# %% [markdown]
# # Assignment SVM & Naive Bayes
#
# 1.  1:  What is a Support Vector Machine (SVM), and how does it work?
#   - A Support Vector Machine (SVM) is a supervised machine learning algorithm used for both classification and regression, but it is most commonly applied in classification tasks.
#
#   - It works by finding the optimal hyperplane that best separates the data points of different classes in a high-dimensional space. The idea is to maximize the margin, which is the distance between the hyperplane and the nearest data points from each class. These closest data points are called support vectors, and they are the most critical elements in defining the decision boundary.
#
#       - If the data is linearly separable, SVM tries to find a straight hyperplane with the maximum margin.
#
#       - If the data is not linearly separable, SVM uses the kernel trick to transform the data into a higher-dimensional space where a separating hyperplane can be found.
#
#   - This makes SVM powerful in handling both simple and complex classification problems.
#
#
# 2.
#   - Hard Margin SVM:
#
#       - Assumes that the data is perfectly linearly separable.
#
#       - It finds a hyperplane that separates the classes without any misclassification.
#
#       - Very strict → does not allow errors, sensitive to noise and outliers.
#
#       - Works only for clean datasets with no overlap.
#
#   - Soft Margin SVM:
#
#       - Introduces a slack variable to allow some misclassification.
#
#       - Balances between maximizing the margin and minimizing classification errors.
#
#       - Controlled by the parameter C (regularization):
#
#           - High C → fewer misclassifications, smaller margin.
#
#           - Low C → allows more misclassifications, larger margin.
#
#     - Works better on real-world noisy datasets.
#
# 3.  What is the Kernel Trick in SVM? Give one example of a kernel and
# explain its use case.
#   - The Kernel Trick is a mathematical technique that allows SVM to operate in a higher-dimensional feature space without explicitly transforming the data.
#
#   - It uses a kernel function to compute similarity between data points in the original space as if they were mapped to a higher dimension.
#
#   - This helps handle non-linear decision boundaries efficiently.
#
#     Example:
#
#     - RBF (Radial Basis Function / Gaussian Kernel):
#
#         - Formula: K(x,x′)=e−γ∣∣x−x′∣∣2
#
#         - It measures similarity based on distance.
#
#         - Useful when classes are not linearly separable, e.g., in image recognition or medical diagnosis.
#
# 4. What is a Naïve Bayes Classifier, and why is it called “naïve”?
#   - Naïve Bayes is a probabilistic classifier based on Bayes’ Theorem with a naïve assumption that all features are independent given the class label.
#
#   - Despite this assumption often being unrealistic, it works surprisingly well in many applications (e.g., spam filtering, sentiment analysis).
#
#   - It’s called “naïve” because of this unrealistic independence assumption.
#
# 5. Describe the Gaussian, Multinomial, and Bernoulli Naïve Bayes variants.
# When would you use each one?
#   - Gaussian Naïve Bayes:
#
#     - Assumes features follow a normal distribution.
#
#     - Used when input features are continuous (e.g., height, weight, age).
#
#   - Multinomial Naïve Bayes:
#
#     - Assumes features are counts/frequencies.
#
#     - Used for text classification with word counts or TF-IDF (e.g., spam detection).
#
#   - Bernoulli Naïve Bayes:
#
#     - Assumes binary features (0/1).
#
#     - Used when features represent presence/absence of a word in a document.

# %%
# 6. Write a Python program to:
# ● Load the Iris dataset
# ● Train an SVM Classifier with a linear kernel
# ● Print the model's accuracy and support vectors.

from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

# Load Iris dataset
iris = datasets.load_iris()
X, y = iris.data, iris.target

# Split dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Train SVM with linear kernel
svm_model = SVC(kernel='linear')
svm_model.fit(X_train, y_train)

# Predictions
y_pred = svm_model.predict(X_test)

# Accuracy and support vectors
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Support Vectors:\n", svm_model.support_vectors_)
# Out:
# Accuracy: 1.0
# Support Vectors:
#  [[4.8 3.4 1.9 0.2]
#  [5.1 3.3 1.7 0.5]
#  [4.5 2.3 1.3 0.3]
#  [5.6 3.  4.5 1.5]
#  [5.4 3.  4.5 1.5]
#  [6.7 3.  5.  1.7]
#  [5.9 3.2 4.8 1.8]
#  [5.1 2.5 3.  1.1]
#  [6.  2.7 5.1 1.6]
#  [6.3 2.5 4.9 1.5]
#  [6.1 2.9 4.7 1.4]
#  [6.5 2.8 4.6 1.5]
#  [6.9 3.1 4.9 1.5]
#  [6.3 2.3 4.4 1.3]
#  [6.3 2.8 5.1 1.5]
#  [6.3 2.7 4.9 1.8]
#  [6.  3.  4.8 1.8]
#  [6.  2.2 5.  1.5]
#  [6.2 2.8 4.8 1.8]
#  [6.5 3.  5.2 2. ]
#  [7.2 3.  5.8 1.6]
#  [5.6 2.8 4.9 2. ]
#  [5.9 3.  5.1 1.8]
#  [4.9 2.5 4.5 1.7]]

# %%
# 7. Write a Python program to:
# ● Load the Breast Cancer dataset
# ● Train a Gaussian Naïve Bayes model
# ● Print its classification report including precision, recall, and F1-score.

from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import classification_report

# Load Breast Cancer dataset
cancer = datasets.load_breast_cancer()
X, y = cancer.data, cancer.target

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Train Gaussian Naïve Bayes
gnb = GaussianNB()
gnb.fit(X_train, y_train)

# Predictions
y_pred = gnb.predict(X_test)

# Classification report
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.90      0.92        63
#            1       0.95      0.96      0.95       108
#
#     accuracy                           0.94       171
#    macro avg       0.94      0.93      0.94       171
# weighted avg       0.94      0.94      0.94       171

# %%
# 8. Write a Python program to:
# ● Train an SVM Classifier on the Wine dataset using GridSearchCV to find the best C and gamma.
# ● Print the best hyperparameters and accuracy.

from sklearn import datasets
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

# Load Wine dataset
wine = datasets.load_wine()
X, y = wine.data, wine.target

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Define parameter grid
param_grid = {
    'C': [0.1, 1, 10],
    'gamma': [0.01, 0.1, 1],
    'kernel': ['rbf']
}

# GridSearchCV
grid = GridSearchCV(SVC(), param_grid, cv=5)
grid.fit(X_train, y_train)

# Predictions
y_pred = grid.predict(X_test)

print("Best Parameters:", grid.best_params_)
print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Best Parameters: {'C': 10, 'gamma': 0.01, 'kernel': 'rbf'}
# Accuracy: 0.6666666666666666

# %%
# 9. Write a Python program to:
# ● Train a Naïve Bayes Classifier on a synthetic text dataset (e.g. using sklearn.datasets.fetch_20newsgroups).
# ● Print the model's ROC-AUC score for its predictions.

from sklearn.datasets import fetch_20newsgroups
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score

# Load dataset
data = fetch_20newsgroups(subset='train', categories=['rec.sport.baseball', 'sci.space'])
X, y = data.data, data.target

# Convert text to features
vectorizer = TfidfVectorizer()
X_vec = vectorizer.fit_transform(X)

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X_vec, y, test_size=0.3, random_state=42)

# Train Naive Bayes
nb_model = MultinomialNB()
nb_model.fit(X_train, y_train)

# Predictions
y_proba = nb_model.predict_proba(X_test)[:,1]

# ROC-AUC Score
print("ROC-AUC Score:", roc_auc_score(y_test, y_proba))
# Out:
# ROC-AUC Score: 0.9983983418127002

# %% [markdown]
# 10. Imagine you’re working as a data scientist for a company that handles
# email communications.
# Your task is to automatically classify emails as Spam or Not Spam. The emails may contain:
#
#   ● Text with diverse vocabulary
#   ● Potential class imbalance (far more legitimate emails than spam)
#   ● Some incomplete or missing data
#
#   Explain the approach you would take to:
#
#   ● Preprocess the data (e.g. text vectorization, handling missing data)
#   ● Choose and justify an appropriate model (SVM vs. Naïve Bayes)
#   ● Address class imbalance
#   ● Evaluate the performance of your solution with suitable metrics
#   And explain the business impact of your solution.
#   - Preprocessing:
#
#       - Convert emails into numerical features using TF-IDF Vectorization.
#
#       - Handle missing data by imputing empty messages as blanks.
#
#       - Lowercasing, removing stopwords, stemming/lemmatization.
#
#   - Model Choice:
#
#       - Naïve Bayes (Multinomial NB): Works well for text, fast, interpretable.
#
#       - SVM: More powerful but slower on large text data. NB is often preferred for spam filtering.
#
#   - Handling Class Imbalance:
#
#       - Use SMOTE / oversampling for minority class.
#
#       - Or adjust class weights in the classifier.
#
#   - Evaluation Metrics:
#
#       - Use Precision, Recall, F1-score, ROC-AUC instead of accuracy (since spam dataset is imbalanced).
#
#       - High recall for spam detection is crucial (catch as much spam as possible).
#
#   - Business Impact:
#
#       - Improves user trust by preventing spam in inbox.
#
#       - Saves time, reduces phishing/scam risks.
#
#       - Enhances company reputation for security.
